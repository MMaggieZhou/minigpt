# %% [markdown]
# <a href="https://colab.research.google.com/github/MMaggieZhou/minigpt/blob/main/gpu_env_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -rf /content/minigpt
# !git clone https://github.com/MMaggieZhou/minigpt.git
# Out:
# Cloning into 'minigpt'...
# remote: Enumerating objects: 54, done.
# remote: Counting objects: 100% (54/54), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 54 (delta 23), reused 43 (delta 14), pack-reused 0 (from 0)
# Receiving objects: 100% (54/54), 134.58 KiB | 1.92 MiB/s, done.
# Resolving deltas: 100% (23/23), done.

# %%
import sys
sys.path.append("/content/minigpt")
BaseDir  = "/content/minigpt"

# %%
from execute import execute, generate

# %%
from execute import set_device
set_device("cuda")

# %%
model, idx_to_char = execute(BaseDir + "/甄嬛传剧本01-10.txt", dmodel=256, dff=1024, dk=128, seq_length=500, batch_size=50, epochs=10)
#generate(model, idx_to_char, max_length=50)
# Out:
# File size: 248968 bytes
# Number of characters in the text: 85746
# Vocabulary size: 2277
# Number of parameters in the model: 8142565
# Feature batch shape: torch.Size([50, 500])
# Labels batch shape: torch.Size([50, 500])
# Starting epoch 1/10
# Epoch 1, Loss: 5.8489
# Starting epoch 2/10
# Epoch 2, Loss: 2.8500
# Starting epoch 3/10
# Epoch 3, Loss: 0.3513
# Starting epoch 4/10
# Epoch 4, Loss: 0.1959
# Starting epoch 5/10
# Epoch 5, Loss: 0.1533
# Starting epoch 6/10
# Epoch 6, Loss: 0.1318
# Starting epoch 7/10
# Epoch 7, Loss: 0.1188
# Starting epoch 8/10
# Epoch 8, Loss: 0.1103
# Starting epoch 9/10
# Epoch 9, Loss: 0.1040
# Starting epoch 10/10
# Epoch 10, Loss: 0.0993

# %%
generate(model, idx_to_char, max_length=500)
# Out:
# Generated indices: [0, 1431, 610, 2274, 1753, 579, 383, 1473, 27, 1916, 1473, 27, 24, 1550, 2089, 627, 17, 0, 1473, 720, 2274, 801, 1969, 1140, 390, 17, 0, 1431, 610, 2274, 1473, 27, 809, 56, 1140, 77, 2276, 0, 1473, 720, 2275, 13, 50, 122, 1295, 786, 96, 881, 845, 14, 2273, 1117, 102, 197, 821, 1603, 1087, 674, 269, 1320, 411, 77, 17, 0, 1431, 610, 2274, 1473, 27, 29, 1087, 500, 2266, 568, 2067, 197, 385, 2276, 0, 1473, 720, 2274, 1495, 2022, 565, 77, 17, 1966, 2022, 1140, 1861, 102, 197, 1471, 1114, 1765, 566, 2273, 860, 1140, 1510, 1510, 148, 500, 185, 97, 56, 17, 2028, 1167, 566, 1471, 1420, 533, 2273, 732, 566, 1117, 1253, 1115, 2103, 2022, 17, 0, 1431, 610, 2274, 1473, 27, 227, 2028, 56, 1914, 2273, 1753, 579, 1066, 501, 1754, 646, 77, 17, 520, 520, 386, 1407, 1756, 667, 2273, 1584, 620, 96, 645, 189, 393, 527, 1868, 17, 0, 1473, 720, 2274, 1972, 348, 544, 1725, 77, 2273, 227, 1678, 148, 767, 21, 2214, 930, 1680, 17, 0, 1431, 610, 2274, 1473, 27, 2028, 56, 2022, 1140, 2273, 226
# ...

# %%
generate(model, idx_to_char, max_length=500)
# Out:
# Generated indices: [0, 1431, 610, 2274, 148, 1087, 17, 0, 1494, 736, 2274, 610, 2276, 1087, 451, 2273, 890, 500, 890, 379, 614, 2270, 0, 1431, 610, 2274, 641, 46, 581, 581, 2273, 148, 364, 819, 890, 2276, 0, 1494, 736, 2274, 1779, 29, 1087, 148, 2273, 69, 128, 1115, 1063, 96, 2273, 890, 623, 872, 1087, 148, 17, 268, 812, 890, 1914, 1904, 343, 144, 237, 148, 2273, 1779, 1087, 890, 128, 17, 0, 1431, 610, 2274, 581, 581, 17, 2271, 463, 2272, 731, 1253, 1115, 97, 56, 29, 575, 770, 2273, 890, 865, 1056, 58, 80, 2273, 2027, 29, 801, 17, 0, 2146, 646, 2274, 29, 801, 340, 925, 581, 581, 361, 890, 2273, 289, 1780, 1066, 1440, 1126, 860, 1851, 28, 1140, 136, 175, 17, 0, 1431, 610, 2274, 668, 792, 860, 1679, 77, 17, 0, 1280, 1128, 2274, 668, 51, 2273, 1860, 340, 436, 197, 1087, 17, 0, 1431, 610, 2274, 148, 1914, 565, 21, 1167, 612, 2276, 0, 149, 197, 2274, 668, 51, 2276, 0, 1431, 610, 2274, 148, 1914, 408, 2273, 1515, 2059, 890, 69, 1732, 1877, 890, 1140, 1510, 1510, 17, 148, 116, 167, 97, 56, 
# ...
